# %%
# !pip -q install langchain langchain-openai orjson

# %% [markdown]
# # final

# %%
# Out:
# :param start_label => 'Accommodation';
# :param start_id => '3013417';
# :param end_label => '';
# :param end_id => '';
# :param transport => 'car';
# :param w_rating => 1.0;
# :param w_reviews => 0.5;
# :param w_dist => 1.0;
# :param exclude_ids => ["37072842", "1133159525", "36541810"];
# :param exclude_cells => [];
# :param budget_per_day => 400000;
# :param travel_day => '토';
# :param season => 'offpeak';
# :param stay_is_weekend => null;
# :param place_plan => [{category: 'Restaurant', count: 1, time: '08:00'}, {category: 'Cafe', count: 1, time: '10:00'}, {category: 'Restaurant', count: 1, time: '12:00'}, {category: 'Attraction', count: 1, time: '14:00'}, {category: 'Cafe', count: 1, time: '16:00'}, {category: 'Restaurant', count: 1, time: '18:00'}];
#
# === 최종 Cypher ===
#
# // 1) 출발 노드
# CALL apoc.cypher.run(
#   'MATCH (n:' + $start_label + ' {id: $id}) RETURN n AS node',
#   {id: $start_id}
# ) YIELD value
# WITH value.node AS start
#
# // 2) 도착 노드 (옵션) — end_id 없으면 dest=NULL
# CALL apoc.do.when(
#   $end_id IS NULL OR $end_id = '',
#   'RETURN null AS node',
#   'MATCH (n:' + $end_label + ' {id: $id}) RETURN n AS node',
#   {id: $end_id}
# ) YIELD value
#
# // 2-1) day/season/raw 주말 플래그만 별칭화
# WITH start, value.node AS dest,
#      $place_plan AS steps,
#      $exclude_ids AS prev_ids,
#      $exclude_cells AS prev_cells,
#      $transport AS transport,
#      $w_rating AS w_rating,
#      $w_reviews AS w_reviews,
#      $w_dist AS w_dist,
#      $budget_per_day AS budget_per_day,
#      $travel_day AS day,
#      $season AS season,
#      $stay_is_weekend AS stay_weekend_raw
#
# // 2-2) day를 사용해 최종 주말 여부 확정
# WITH start, dest, steps, prev_ids, prev_cells,
#      transport, w_rating, w_reviews, w_dist,
#      budget_per_day, day, season,
#      coalesce(stay_weekend_raw, day IN ['금','토']) AS stay_is_weekend
#
# // 2-3) 숙소비 계산 + idxs 생성
# WITH start, dest, steps, prev_ids, prev_cells,
#      transport, w_rating, w_reviews, w_dist,
#      budget_per_day, day, season, stay_is_weekend,
#      CASE
#        WHEN 'Accommodation' IN labels(start) THEN
#          CASE
#            WHEN season = 'peak' AND stay_is_weekend
#              THEN coalesce(toInteger(start.peak_weekend_price_avg), 0)
#            WHEN season = 'peak' AND NOT stay_is_weekend
#              THEN coalesce(toInteger(start.peak_weekday_price_avg), 0)
#            WHEN season = 'offpeak' AND stay_is_weekend
#              THEN coalesce(toInteger(start.offpeak_weekend_price_avg), 0)
#            ELSE
#              coalesce(toInteger(start.offpeak_weekday_price_avg), 0)
#          END
#        ELSE 0
#      END AS lodging_cost,
#      range(0, size(steps)-1) AS idxs
#
# // 3) 반복
# UNWIND idxs AS i
# WITH i, steps[i] AS step, steps, start, dest, day,
#      prev_ids, prev_cells, transport, w_rating, w_reviews, w_dist,
#      budget_per_day, lodging_cost
#
# // 4) 추천 서브쿼리
# CALL {
#   WITH i, step, steps, start, dest, day,
#        prev_ids, prev_cells, transport, w_rating, w_reviews, w_dist,
#        budget_per_day, lodging_cost
#
#   MATCH (p)
#
#   // opening_hours 전처리 (요일 라인만 추출 → "HH:MM - HH:MM" 파싱)
#   WITH p, i, step, steps, start, dest, day,
#        prev_ids, prev_cells, transport, w_rating, w_reviews, w_dist,
#        budget_per_day, lodging_cost,
#        [h IN coalesce(p.opening_hours, []) WHERE h STARTS WITH day + ':' AND h CONTAINS ' - '] AS day_rows
#   WITH p, i, step, steps, start, dest, day,
#        prev_ids, prev_cells, transport, w_rating, w_reviews, w_dist,
#        budget_per_day, lodging_cost,
#        CASE
#          WHEN size(day_rows)=0 THEN NULL
#          ELSE split( split(day_rows[0], ': ')[1], ' - ')
#        END AS hh
#   WITH p, i, step, steps, start, dest, day,
#        prev_ids, prev_cells, transport, w_rating, w_reviews, w_dist,
#        budget_per_day, lodging_cost,
#        CASE WHEN hh IS NULL THEN NULL ELSE time(hh[0]) END AS open_t,
#        CASE WHEN hh IS NULL THEN NULL ELSE time(hh[1]) END AS close_t
#
#   WHERE
#     (
#       (step.category = 'Cafe'       AND p:Restaurant AND p.sub_category CONTAINS '카페') OR
#       (step.category = 'Restaurant' AND p:Restaurant AND (p.sub_category IS NULL OR NOT p.sub_category CONTAINS '카페')) OR
#       (step.category = 'Attraction' AND p:Attraction)
#     )
#     AND NOT coalesce(p.id, p.place_id, p.festival_title) IN prev_ids
#     AND NOT p.cell_key IN prev_cells
#     AND p.location IS NOT NULL
#     AND (
#       open_t IS NULL OR (time(step.time) >= open_t AND time(step.time) <= close_t - duration('PT30M'))
#     )
#
#   OPTIONAL MATCH (start)-[r1:NEAR]-(p)
#   WHERE r1.bridge IS NULL
#   WITH p, i, step, steps, dest, transport, w_rating, w_reviews, w_dist,
#        budget_per_day, lodging_cost, open_t, close_t, day,
#        CASE WHEN r1 IS NULL THEN 99999 ELSE r1.distance_m / 1000.0 END AS dist_from_start
#
#   OPTIONAL MATCH (p)-[r2:NEAR]-(dest)
#   WHERE dest IS NOT NULL AND r2.bridge IS NULL
#   WITH p, i, step, steps, dest, transport, w_rating, w_reviews, w_dist,
#        budget_per_day, lodging_cost, open_t, close_t, dist_from_start, day,
#        CASE WHEN dest IS NULL OR r2 IS NULL THEN 99999 ELSE r2.distance_m / 1000.0 END AS dist_to_dest,
#
#        // 안전 캐스팅
#        CASE WHEN p.rating IS NULL OR p.rating = '' THEN 0 ELSE toFloat(p.rating) END AS rating,
#        CASE WHEN p.all_review_count IS NULL OR p.all_review_count = '' THEN 0 ELSE toInteger(p.all_review_count) END AS review_count,
#
#        // 비용 계산
#        CASE
#          WHEN step.category = 'Attraction' THEN
#            CASE WHEN p.entrance_fee IS NULL OR p.entrance_fee = '' THEN 0 ELSE toInteger(p.entrance_fee) END
#          WHEN step.category IN ['Restaurant','Cafe'] THEN
#            CASE WHEN p.avg_price IS NULL OR p.avg_price = '' THEN 0 ELSE toInteger(p.avg_price) * 2 END
#          ELSE 0
#        END AS cost,
#
#        size(steps) AS total_steps
#
#   // 점수/패널티 (마지막 스텝 & dest=NULL이면 패널티 0)
#   WITH p, i, step, cost, total_steps, transport, dest, day,
#        w_rating * rating + w_reviews * log(1 + review_count) AS base_score,
#        CASE
#          WHEN i = total_steps - 1 THEN
#            CASE
#              WHEN dest IS NULL THEN 0
#              WHEN transport = 'walk' THEN w_dist * (dist_to_dest ^ 1.2)
#              ELSE w_dist * CASE WHEN dist_to_dest <= 7 THEN 0 ELSE (dist_to_dest - 7) END
#            END
#          ELSE
#            CASE
#              WHEN transport = 'walk' THEN w_dist * (dist_from_start ^ 1.2)
#              ELSE w_dist * CASE WHEN dist_from_start <= 7 THEN 0 ELSE (dist_from_start - 7) END
#            END
#        END AS dist_penalty,
#        budget_per_day - lodging_cost AS remaining_budget
#
#   WITH p, i, step, cost, (base_score - dist_penalty) AS score, remaining_budget, day
#   WHERE cost <= remaining_budget
#
#   // --- 정렬 & 슬라이스: 상위 count개 보장 ---
#   WITH i, step, cost, score, p, day
#   ORDER BY score DESC, cost ASC
#   WITH step, collect({
#     index: i,
#     id: coalesce(p.id, p.place_id, p.festival_title),
#     label: labels(p)[0],
#     name: coalesce(p.name, p.place_name),
#     cell_key: p.cell_key,
#     cost: cost,
#     score: score
#   }) AS ranked, day
#
#   RETURN CASE
#            WHEN size(ranked) >= toInteger(step.count) THEN ranked[0..toInteger(step.count)]
#            ELSE ranked
#          END AS selected
# }
#
# // 5) 결과
# WITH apoc.coll.flatten(collect(selected)) AS raw_results
# UNWIND raw_results AS result
# RETURN
#   result.index,
#   result.id,
#   result.label,
#   result.name,
#   result.cell_key,
#   result.cost,
#   round(result.score, 2) AS score
# ORDER BY result.index ASC

# %%
import json
from typing import Dict
from neo4j import GraphDatabase

# --------------------------------------------------------------------
# PARAMS 예시
# --------------------------------------------------------------------
PARAMS = {
    "start_label": "Accommodation",
    "start_id": "3013417",
    "end_label": "",
    "end_id": "",
    "transport": "car",
    "w_dist": 1.0,
    "w_branch": 0.4,
    "w_budget": 0.8,
    "exclude_ids": ["37072842","1133159525","36541810"],
    "exclude_cells": [],
    "budget_per_day": 400000,
    "travel_day": "토",
    "season": "offpeak",
    "stay_is_weekend": None,
    "place_plan": [
        {"category":"Restaurant","count":1,"time":"08:00"},
        {"category":"Cafe","count":1,"time":"10:00"},
        {"category":"Restaurant","count":1,"time":"12:00"},
        {"category":"Attraction","count":1,"time":"14:00"},
        {"category":"Cafe","count":1,"time":"16:00"},
        {"category":"Restaurant","count":1,"time":"18:00"}
    ]
}

# ---------- :param 블록 생성 ----------
def _cy(v):
    if v is None:
        return "null"
    if isinstance(v, str):
        return "'" + v.replace("'", "\\'") + "'"
    return json.dumps(v, ensure_ascii=False)

def to_param_block(p: Dict) -> str:
    keys = [
        "start_label","start_id","end_label","end_id",
        "transport","w_dist","w_branch","w_budget",
        "exclude_ids","exclude_cells",
        "budget_per_day","travel_day","season","stay_is_weekend",
    ]
    lines = [f":param {k} => {_cy(p.get(k))};" for k in keys]
    plan = "[" + ", ".join(
        [ "{category: " + _cy(s['category']) +
          ", count: " + str(s['count']) +
          ", time: " + _cy(s['time']) + "}" for s in p["place_plan"] ]
    ) + "]"
    lines.append(f":param place_plan => {plan};")
    return "\n".join(lines)

# ---------- Cypher 템플릿 (긴 쿼리 그대로) ----------
import json
from typing import Dict
from neo4j import GraphDatabase

# --------------------------------------------------------------------
# PARAMS 예시
# --------------------------------------------------------------------
PARAMS = {
    "start_label": "Accommodation",
    "start_id": "3013417",
    "end_label": "",
    "end_id": "",
    "transport": "car",
    "w_dist": 1.0,
    "w_branch": 0.4,
    "w_budget": 0.8,
    "exclude_ids": ["37072842","1133159525","36541810"],
    "exclude_cells": [],
    "budget_per_day": 400000,
    "travel_day": "토",
    "season": "offpeak",
    "stay_is_weekend": None,
    "place_plan": [
        {"category":"Restaurant","count":1,"time":"08:00"},
        {"category":"Cafe","count":1,"time":"10:00"},
        {"category":"Restaurant","count":1,"time":"12:00"},
        {"category":"Attraction","count":1,"time":"14:00"},
        {"category":"Cafe","count":1,"time":"16:00"},
        {"category":"Restaurant","count":1,"time":"18:00"}
    ]
}

# ---------- :param 블록 생성 ----------
def _cy(v):
    if v is None:
        return "null"
    if isinstance(v, str):
        return "'" + v.replace("'", "\\'") + "'"
    return json.dumps(v, ensure_ascii=False)

def to_param_block(p: Dict) -> str:
    keys = [
        "start_label","start_id","end_label","end_id",
        "transport","w_dist","w_branch","w_budget",
        "exclude_ids","exclude_cells",
        "budget_per_day","travel_day","season","stay_is_weekend",
    ]
    lines = [f":param {k} => {_cy(p.get(k))};" for k in keys]
    plan = "[" + ", ".join(
        [ "{category: " + _cy(s['category']) +
          ", count: " + str(s['count']) +
          ", time: " + _cy(s['time']) + "}" for s in p["place_plan"] ]
    ) + "]"
    lines.append(f":param place_plan => {plan};")
    return "\n".join(lines)

# ---------- Cypher 템플릿 (긴 쿼리 그대로) ----------
CYPHER_TEMPLATE = """
// 1) 출발 노드
CALL apoc.cypher.run(
  'MATCH (n:' + $start_label + ' {id: $id}) RETURN n AS node',
  {id: $start_id}
) YIELD value
WITH value.node AS start

// 2) 도착 노드 (옵션)
CALL apoc.do.when(
  $end_id IS NULL OR $end_id = '',
  'RETURN null AS node',
  'MATCH (n:' + $end_label + ' {id: $id}) RETURN n AS node',
  {id: $end_id}
) YIELD value
WITH start, value.node AS dest,
     $place_plan AS steps,
     $exclude_ids AS prev_ids,
     $exclude_cells AS prev_cells,
     $transport AS transport,
     toFloat($w_dist)   AS w_dist,
     toFloat($w_branch) AS w_branch,
     toFloat($w_budget) AS w_budget,
     $budget_per_day AS budget_per_day,
     $travel_day AS day,
     $season AS season,
     $stay_is_weekend AS stay_weekend_raw

// 2-2) 주말 여부 확정
WITH start, dest, steps, prev_ids, prev_cells,
     transport, w_dist, w_branch, w_budget,
     budget_per_day, day, season,
     coalesce(stay_weekend_raw, day IN ['금','토']) AS stay_is_weekend

// 2-3) 숙소비 + idxs
WITH start, dest, steps, prev_ids, prev_cells,
     transport, w_dist, w_branch, w_budget,
     budget_per_day, day, season, stay_is_weekend,
     CASE
       WHEN 'Accommodation' IN labels(start) THEN
         CASE
           WHEN season = 'peak'    AND  stay_is_weekend THEN coalesce(toInteger(start.peak_weekend_price_avg), 0)
           WHEN season = 'peak'    AND NOT stay_is_weekend THEN coalesce(toInteger(start.peak_weekday_price_avg), 0)
           WHEN season = 'offpeak' AND  stay_is_weekend THEN coalesce(toInteger(start.offpeak_weekend_price_avg), 0)
           ELSE coalesce(toInteger(start.offpeak_weekday_price_avg), 0)
         END
       ELSE 0
     END AS lodging_cost,
     range(0, size(steps)-1) AS idxs

// 3) 반복
UNWIND idxs AS i
WITH i, steps[i] AS step, steps, start, dest, day,
     prev_ids, prev_cells, transport, w_dist, w_branch, w_budget,
     budget_per_day, lodging_cost

// 4) 추천 서브쿼리
CALL {
  WITH i, step, steps, start, dest, day,
       prev_ids, prev_cells, transport, w_dist, w_branch, w_budget,
       budget_per_day, lodging_cost

  MATCH (p)
  WHERE
    (
      // ✅ Cafe: sub_category에 "카페" 포함
      (step.category = 'Cafe' AND (
         p:Restaurant OR (p.category IS NOT NULL AND p.category CONTAINS '음식')
      ) AND (p.sub_category IS NOT NULL AND p.sub_category CONTAINS '카페'))

      OR

      // ✅ Restaurant: sub_category에 "카페" 없는 음식점
      (step.category = 'Restaurant' AND (
         p:Restaurant OR (p.category IS NOT NULL AND p.category CONTAINS '음식')
      ) AND (p.sub_category IS NULL OR NOT p.sub_category CONTAINS '카페'))

      OR

      // ✅ Attraction
      (step.category = 'Attraction' AND (
         p:Attraction OR
         (p.category IS NOT NULL AND (
            p.category CONTAINS '명소' OR
            p.category CONTAINS '관광' OR
            p.category CONTAINS '박물관' OR
            p.category CONTAINS '미술관' OR
            p.category CONTAINS '체험'
         ))
      ))
    )
    AND NOT coalesce(p.id, p.place_id, p.festival_title) IN prev_ids
    AND NOT p.cell_key IN prev_cells
    AND p.location IS NOT NULL

  // 영업시간 필터
  WITH p, i, step, steps, start, dest, day,
       transport, w_dist, w_branch, w_budget,
       budget_per_day, lodging_cost,
       [h IN coalesce(p.opening_hours, []) WHERE h STARTS WITH day + ':' AND h CONTAINS ' - '] AS day_rows
  WITH p, i, step, steps, start, dest, day,
       transport, w_dist, w_branch, w_budget,
       budget_per_day, lodging_cost,
       CASE WHEN size(day_rows)=0 THEN NULL ELSE split( split(day_rows[0], ': ')[1], ' - ') END AS hh
  WITH p, i, step, steps, start, dest, day,
       transport, w_dist, w_branch, w_budget,
       budget_per_day, lodging_cost,
       CASE WHEN hh IS NULL THEN NULL ELSE time(hh[0]) END AS open_t,
       CASE WHEN hh IS NULL THEN NULL ELSE time(hh[1]) END AS close_t
  WHERE open_t IS NULL OR (time(step.time) >= open_t AND time(step.time) <= close_t - duration('PT30M'))

  // 거리 계산 (start 기준)
  OPTIONAL MATCH (start)-[r1:NEAR]-(p) WHERE r1.bridge IS NULL
  WITH p, i, step, steps, transport, w_dist, w_branch, w_budget,
       budget_per_day, lodging_cost,
       CASE WHEN r1 IS NULL THEN 99999 ELSE r1.distance_m / 1000.0 END AS dist_from_start,
       coalesce(p.place_name, p.name) AS pname,
       p.sub_category AS sub_category,
       size(steps) AS total_steps,
       CASE
         WHEN step.category = 'Attraction' THEN coalesce(toInteger(p.entrance_fee), 0)
         WHEN step.category IN ['Restaurant','Cafe'] THEN
           CASE WHEN p.avg_price IS NULL THEN 0
                ELSE toInteger(round(toFloat(p.avg_price))) * 2 END
         ELSE 0
       END AS cost

  WHERE cost <= (budget_per_day - lodging_cost)

  // per-step cap
  WITH p, i, step, cost, dist_from_start, pname, sub_category,
       transport, w_dist, w_branch, w_budget,
       budget_per_day, lodging_cost, total_steps,
       (toFloat(budget_per_day - lodging_cost) / toFloat(total_steps)) AS per_step_cap

  WITH p, i, step, cost, dist_from_start, pname, sub_category,
       transport, w_dist, w_branch, w_budget, per_step_cap,
       abs(1.0 - (CASE WHEN per_step_cap > 0 THEN cost / per_step_cap ELSE 1.0 END)) AS budget_diff

  // 이동/지점 패널티 + 예산 보너스
  WITH p, i, step, cost, pname, sub_category,
       (CASE
         WHEN transport='walk' THEN w_dist*(dist_from_start^1.2)
         ELSE w_dist*CASE WHEN dist_from_start <= 7 THEN 0 ELSE (dist_from_start-7) END
       END) AS move_penalty,
       CASE WHEN pname IS NOT NULL AND trim(toString(pname)) ENDS WITH '점'
            THEN w_branch ELSE 0 END AS branch_penalty,
       (w_budget * (1.0 - budget_diff)) AS budget_bonus

  // 최종 점수
  WITH i, step, cost, p, sub_category,
       (budget_bonus - move_penalty - branch_penalty) AS score

  ORDER BY score DESC, cost DESC
  WITH step, collect({
    index: i,
    id: coalesce(p.place_id, p.id, p.festival_title),
    label: labels(p)[0],
    name: coalesce(p.place_name, p.name),
    cell_key: p.cell_key,
    cost: cost,
    score: score,
    sub_category: coalesce(sub_category, "")
  }) AS ranked
  RETURN ranked[0..toInteger(step.count)] AS selected
}

// 5) 결과
WITH apoc.coll.flatten(collect(selected)) AS raw_results
UNWIND raw_results AS result
RETURN
  result.index,
  result.id,
  result.label,
  result.name,
  result.cell_key,
  result.cost,
  round(result.score, 2) AS score,
  result.sub_category
ORDER BY result.index ASC

""".strip()

# ---------- 실제 DB 실행 ----------
def run_query(params: Dict, uri="bolt://localhost:7687", user="neo4j", password="password"):
    """
    Neo4j에 연결해서 param_block + CYPHER_TEMPLATE 실행
    """
    param_block = to_param_block(params)
    query = param_block + "\n" + CYPHER_TEMPLATE
    
    driver = GraphDatabase.driver(uri, auth=(user, password))
    results = []
    with driver.session() as sess:
        res = sess.run(query)
        for r in res:
            results.append(dict(r))
    driver.close()
    return results

# ===================== 실행 예제 =====================
if __name__ == "__main__":
    print("=== PARAM BLOCK ===")
    print(to_param_block(PARAMS))
    print("\n=== CYPHER 실행 결과 ===")
    rows = run_query(PARAMS, uri="bolt://localhost:7687", user="neo4j", password="your_password_here")
    for row in rows:
        print(row)

# ---------- 실제 DB 실행 ----------
def run_query(params: Dict, uri="bolt://localhost:7687", user="neo4j", password="password"):
    """
    Neo4j에 연결해서 param_block + CYPHER_TEMPLATE 실행
    """
    param_block = to_param_block(params)
    query = param_block + "\n" + CYPHER_TEMPLATE
    
    driver = GraphDatabase.driver(uri, auth=(user, password))
    results = []
    with driver.session() as sess:
        res = sess.run(query)
        for r in res:
            results.append(dict(r))
    driver.close()
    return results

# ===================== 실행 예제 =====================
if __name__ == "__main__":
    print("=== PARAM BLOCK ===")
    print(to_param_block(PARAMS))
    print("\n=== CYPHER 실행 결과 ===")
    rows = run_query(PARAMS, uri="bolt://localhost:7687", user="neo4j", password="your_password_here")
    for row in rows:
        print(row)
# Out:
# === PARAM BLOCK ===
# :param start_label => 'Accommodation';
# :param start_id => '3013417';
# :param end_label => '';
# :param end_id => '';
# :param transport => 'car';
# :param w_dist => 1.0;
# :param w_branch => 0.4;
# :param w_budget => 0.8;
# :param exclude_ids => ["37072842", "1133159525", "36541810"];
# :param exclude_cells => [];
# :param budget_per_day => 400000;
# :param travel_day => '토';
# :param season => 'offpeak';
# :param stay_is_weekend => null;
# :param place_plan => [{category: 'Restaurant', count: 1, time: '08:00'}, {category: 'Cafe', count: 1, time: '10:00'}, {category: 'Restaurant', count: 1, time: '12:00'}, {category: 'Attraction', count: 1, time: '14:00'}, {category: 'Cafe', count: 1, time: '16:00'}, {category: 'Restaurant', count: 1, time: '18:00'}];
#
# === CYPHER 실행 결과 ===
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:498, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, keep_alive, ssl_context)
#     497 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 498 s.connect(resolved_address)
#     499 s.settimeout(t)
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_bolt_socket.py:329, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     328 try:
# --> 329     s = cls._connect_secure(
#     330         resolved_address, tcp_timeout, keep_alive, ssl_context
#     331     )
#     332     agreed_version = s._handshake(resolved_address, deadline)
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:521, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, keep_alive, ssl_context)
#     520 if isinstance(error, OSError):
# --> 521     raise ServiceUnavailable(
#     522         "Failed to establish connection to "
#     523         f"{resolved_address!r} (reason {error})"
#     524     ) from error
#     525 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[1], line 320
#     318 print(to_param_block(PARAMS))
#     319 print("\n=== CYPHER 실행 결과 ===")
# --> 320 rows = run_query(PARAMS, uri="bolt://localhost:7687", user="neo4j", password="your_password_here")
#     321 for row in rows:
#     322     print(row)
#
# Cell In[1], line 309, in run_query(params, uri, user, password)
#     307 results = []
#     308 with driver.session() as sess:
# --> 309     res = sess.run(query)
#     310     for r in res:
#     311         results.append(dict(r))
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\work\session.py:305, in Session.run(self, query, parameters, **kwargs)
#     302     self._auto_result._buffer_all()
#     304 if not self._connection:
# --> 305     self._connect(self._config.default_access_mode)
#     306     assert self._connection is not None
#     307 cx = self._connection
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\work\session.py:126, in Session._connect(self, access_mode, **acquire_kwargs)
#     124     access_mode = self._config.default_access_mode
#     125 try:
# --> 126     super()._connect(
#     127         access_mode, auth=self._config.auth, **acquire_kwargs
#     128     )
#     129 except asyncio.CancelledError:
#     130     self._handle_cancellation(message="_connect")
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\work\workspace.py:181, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)    178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#     180 acquire_kwargs_.update(acquire_kwargs)
# --> 181 self._connection = self._pool.acquire(**acquire_kwargs_)
#     182 if (
#     183     target_db.guessed
#     184     and not self._pinned_database
#    (...)    188     # support SSR.
#     189     # => we need to fall back to explicit home database resolution
#     190     log.debug(
#     191         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     192         "falling back to explicit home database resolution",
#     193     )
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_pool.py:678, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     671 deadline = acquisition_timeout_to_deadline(timeout)
#     672 log.debug(
#     673     "[#0000]  _: <POOL> acquire direct connection, "
#     674     "access_mode=%r, database=%r",
#     675     access_mode,
#     676     database,
#     677 )
# --> 678 return self._acquire(
#     679     self.address, auth, deadline, liveness_check_timeout, unprepared
#     680 )
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_pool.py:418, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     413             raise ConnectionAcquisitionTimeoutError(
#     414                 "failed to obtain a connection from the pool within "
#     415                 f"{deadline.original_timeout!r}s (timeout)"
#     416             )
#     417 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418 return connection_creator()
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_pool.py:231, in IOPool._acquire_new_later.<locals>.connection_creator()
#     229 try:
#     230     try:
# --> 231         connection = self.opener(
#     232             address, auth or self.pool_config.auth, deadline
#     233         )
#     234     except ServiceUnavailable:
#     235         self.deactivate(address)
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_pool.py:638, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     637 def opener(addr, auth_manager, deadline):
# --> 638     return Bolt.open(
#     639         addr,
#     640         auth_manager=auth_manager,
#     641         deadline=deadline,
#     642         routing_context=None,
#     643         pool_config=pool_config,
#     644     )
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_bolt.py:367, in Bolt.open(address, auth_manager, deadline, routing_context, pool_config)
#     364 if deadline is None:
#     365     deadline = Deadline(None)
# --> 367 s, protocol_version = BoltSocket.connect(
#     368     address,
#     369     tcp_timeout=pool_config.connection_timeout,
#     370     deadline=deadline,
#     371     custom_resolver=pool_config.resolver,
#     372     ssl_context=pool_config.get_ssl_context(),
#     373     keep_alive=pool_config.keep_alive,
#     374 )
#     376 pool_config.protocol_version = protocol_version
#     377 protocol_handlers = Bolt.protocol_handlers
#
# File c:\Users\changjin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_bolt_socket.py:376, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     374 else:
#     375     error_strs = "\n".join(map(str, errors))
# --> 376     raise ServiceUnavailable(
#     377         f"Couldn't connect to {address} (resolved to {address_strs}):"
#     378         f"\n{error_strs}"
#     379     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)
